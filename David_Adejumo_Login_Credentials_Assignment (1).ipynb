# %% [markdown]
# <h2> Login Credentials System </h2>

# %%
"""This is a database for three different individuals stored using dictionary data structure.
The database is arranged in the format username:Password
Thus the key is the username while the value is the password"""

biodata = {
    'Sheyman':'wellington@324XY',
    'Bams':'skilharvest@901DF',
    'Adiel':'Jazzmusic@234KJ'
}

# %%
#input login credentials
username = str(input('Enter your uername, (Note that username is case sensitive): '))
password = str(input('Enter your password, (Note that password is case sensitive): '))

#check if the details entered match any of those in the dictionary above
if username == 'Sheyman' and password == 'wellington@324XY':
    print(f"Login successful. Hello {username}, You are welcome to Skilharvest")
elif username == 'Sheyman' and password != 'wellington@324XY':
        print(f"Hello {username}, you have entered a wrong password, kindly click on forgot password to retrieve your password. Note that your password is case sensitive")

elif username == 'Bams' and password == 'skilharvest@901DF':
    print(f"Login successful. Hello {username}, You are welcome to Skilharvest")
elif username == 'Bams' and password != 'skilharvest@901DF':
        print(f"Hello {username}, you have entered a wrong password, kindly click on forgot password to retrieve your password. Note that your password is case sensitive")

elif username == 'Adiel' and password == 'Jazzmusic@234KJ':
    print(f"Login successful. Hello {username}, You are welcome to Skilharvest")
elif username == 'Adiel' and password != 'Jazzmusic@234KJ':
        print(f"Hello {username}, you have entered a wrong password, kindly click on forgot password to retrieve your password. Note that your password is case sensitive")

else:
    print("Invalid login credentials")
# Out:
# Enter your uername, (Note that username is case sensitive): Bams
# Enter your password, (Note that password is case sensitive): skilharvest@901DF
# Login successful. Hello Bams, You are welcome to Skilharvest
